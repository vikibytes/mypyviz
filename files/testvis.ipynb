# %% [markdown]
# <a href="https://colab.research.google.com/github/vikibytes/mypyviz/blob/master/files/testvis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
# %matplotlib inline

# %%
X = np.linspace(-np.pi, np.pi, 1024, endpoint=True)
C, S = np.cos(X), np.sin(X)

# %%
plt.plot(X, C);
plt.plot(X, S);

# %%
plt.figure(figsize=(12, 6), dpi=80)
plt.subplot(111)
X = np.linspace(-2*np.pi, 2*np.pi, 256, endpoint=True)
C, S = np.cos(X), np.sin(X)

plt.plot(X, C, color="blue", linewidth=1.0, linestyle="-")
plt.plot(X, S, color="green", linewidth=1.0, linestyle="-")

# Set x,y limits
plt.xlim(-6.0, 6.0)
plt.ylim(-1., 1.)

# Set x-ticks, y-ticks
plt.xticks(np.linspace(-6, 6, 13, endpoint=True))
plt.yticks(np.linspace(-1, 1, 5, endpoint=True))
# Out:
# ([<matplotlib.axis.YTick at 0x7fdfd67c19e8>,
# ...
#  <a list of 5 Text yticklabel objects>)
